# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key
api_key = "aa40bd0903ee6738f36fafd6c66d94c3"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url= f"http://api.openweathermap.org/data/2.5/weather?APPID={api_key}&q="
test_cities=["london","seoul","new york"]
whether_info=[]
for city in cities:
#for city in test_cities:
    results=requests.get(url+city).json()
 
    city_name = {}

    
    try:
        city_name["Latitude"]=results ['coord']['lat']
        city_name["Longitude"]=results['coord']['lon']
        city_name['Temperature (F)']=results['main']['temp'] 
        city_name['Humidity (%)']=results['main']['humidity']
        city_name['Cloudiness (%)']=results['clouds']['all']
        city_name['Wind Speed (mph)']=results['wind']['speed']
        city_name["City"]=results ['name']
        wheather_info.append(city_name)

        
    except :
        
        print('Missing weather information...skip')
# Out:
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# Missing weather information...skip
# ...

# %%
#create a dataframe to store all the cities and countries generated with citipy

df_cities = pd.DataFrame(whether_info)

df_cities.to_csv("whether_info.csv",index=False)

df_cities.head()
# Out:
#    Latitude  Longitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0    -53.16     -70.91           289.46            48              56
# 1     70.00     135.55           237.31            92              14
# 2    -46.19     168.86           285.93            63              53
# 3    -42.78     147.06           289.25            67              75
# 4     52.47      96.11           256.37            88             100
#
#    Wind Speed (mph)          City
# 0              6.70  Punta Arenas
# 1              3.68     Ust-Kuyga
# 2              7.60       Mataura
# 3              3.10   New Norfolk
# 4              0.74    Toora-Khem

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#df_cities_table.groupby(['Latitude'])['Temperature (F)'].mean().reset_index().style.background_gradient(cmap=cm)
temp_cities_df= df_cities.loc[:,['City', 'Latitude','Temperature (F)']]
temp_cities_df
# Out:
#              City  Latitude  Temperature (F)
# 0    Punta Arenas    -53.16           289.46
# 1       Ust-Kuyga     70.00           237.31
# 2         Mataura    -46.19           285.93
# 3     New Norfolk    -42.78           289.25
# 4      Toora-Khem     52.47           256.37
# ..            ...       ...              ...
# 559          Sibu      2.29           298.15
# 560     Montlucon     46.33           274.28
# 561     Wanlaweyn      2.62           299.70
# 562        Xining     36.62           265.41
# 563    Carinhanha    -14.30           298.98
#
# [564 rows x 3 columns]

# %%
plt.style.use('dark_background')
plt.figure(figsize=(18,5))
plt.scatter(df_cities['Latitude'],df_cities['Temperature (F)'], color = 'red',s=20)
plt.title('Temperature (F) vs. Latitude',fontsize=(18));
plt.xlim(-90,90)
plt.ylabel('Temperature (F)', fontsize=(15));
plt.xlabel('Latitude',fontsize=(15));

#df_cities_table.groupy(['Latitute'])['Humidity(%)'], mean(.reset_index(.style.background_gradient(cmap=cm)

# %%
#df_cities_table.groupy(['Latitude'])['Humidity(%)'], mean().reset_index().style.background_gradient(cmap=cm)
#df_cities_table.head()
hum_cities_df= df_cities.loc[:,['City', 'Latitude','Humidity(%)']]
hum_cities_df
# Out:
#              City  Latitude  Humidity(%)
# 0    Punta Arenas    -53.16          NaN
# 1       Ust-Kuyga     70.00          NaN
# 2         Mataura    -46.19          NaN
# 3     New Norfolk    -42.78          NaN
# 4      Toora-Khem     52.47          NaN
# ..            ...       ...          ...
# 559          Sibu      2.29          NaN
# 560     Montlucon     46.33          NaN
# 561     Wanlaweyn      2.62          NaN
# 562        Xining     36.62          NaN
# 563    Carinhanha    -14.30          NaN
#
# [564 rows x 3 columns]

# %%
plt.figure(figsize=(18,5))
plt.scatter(df_cities['Latitude'],df_cities['Humidity (%)'], color = 'white',s=20)
plt.title('Humidity (%) vs. Latitude',fontsize=(18));
plt.xlim(-90,90)
plt.ylabel('Humidity (%)', fontsize=(15));
plt.xlabel('Latitude',fontsize=(15));

# %%
#df_cities_table.groupy(['Latitude'])['Cloudiness (%)'], mean().reset_index().style.background_gradient(cmap=cm)
#df_cities_table.head()
clu_cities_table_df= df_cities.loc[:,['City', 'Latitude','Cloudiness (%)']]
clu_cities_table_df
# Out:
#              City  Latitude  Cloudiness (%)
# 0    Punta Arenas    -53.16              56
# 1       Ust-Kuyga     70.00              14
# 2         Mataura    -46.19              53
# 3     New Norfolk    -42.78              75
# 4      Toora-Khem     52.47             100
# ..            ...       ...             ...
# 559          Sibu      2.29              75
# 560     Montlucon     46.33              96
# 561     Wanlaweyn      2.62               3
# 562        Xining     36.62             100
# 563    Carinhanha    -14.30              97
#
# [564 rows x 3 columns]

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(18,5))
plt.scatter(df_cities['Latitude'],df_cities['Cloudiness (%)'], color = 'pink',s=20)
plt.title('Cloudiness (%) vs. Latitude',fontsize=(18));
plt.xlim(-90,90)
plt.ylabel('Cloudiness (%)', fontsize=(15));
plt.xlabel('Latitude',fontsize=(15));

# %%
#df_cities_table.groupy(['Latitude'])['Wind Speed (mph)'], mean().reset_index().style.background_gradient(cmap=cm)
#df_cities_table.head()
wds_cities_df= df_cities.loc[:,['City', 'Latitude','Wind Speed (mph)']]
wds_cities_df
# Out:
#              City  Latitude  Wind Speed (mph)
# 0    Punta Arenas    -53.16              6.70
# 1       Ust-Kuyga     70.00              3.68
# 2         Mataura    -46.19              7.60
# 3     New Norfolk    -42.78              3.10
# 4      Toora-Khem     52.47              0.74
# ..            ...       ...               ...
# 559          Sibu      2.29              0.17
# 560     Montlucon     46.33              2.94
# 561     Wanlaweyn      2.62              7.28
# 562        Xining     36.62              1.79
# 563    Carinhanha    -14.30              1.93
#
# [564 rows x 3 columns]

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(18,5))
plt.scatter(df_cities['Latitude'],df_cities['Wind Speed (mph)'], color = 'yellow',s=20)
plt.title('Wind Speed (mph) vs. Latitude',fontsize=(18));
plt.xlim(-90,90)
plt.ylabel('Wind Speed (mph)', fontsize=(15));
plt.xlabel('Latitude',fontsize=(15));
